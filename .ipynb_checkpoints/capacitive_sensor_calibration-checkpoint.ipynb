std_dev_set_40oz = np.std(cycle_time_40oz)
std_dev_set_60oz = np.std(cycle_time_60oz)
std_dev_set_80oz = np.std(cycle_time_80oz)
std_dev_set_100oz = np.std(cycle_time_100oz)
std_dev_set_120oz = np.std(cycle_time_120oz)
std_dev_set_140oz = np.std(cycle_time_140oz)
std_dev_set_160oz = np.std(cycle_time_160oz)
std_dev_set_180oz = np.std(cycle_time_180oz)
std_dev_set_200oz = np.std(cycle_time_200oz)
std_dev_set_220oz = np.std(cycle_time_220oz)
std_dev_set_240oz = np.std(cycle_time_240oz)
std_dev_set_260oz = np.std(cycle_time_260oz)
std_dev_set_280oz = np.std(cycle_time_280oz)
std_dev_set_300oz = np.std(cycle_time_300oz)
std_dev_set_320oz = np.std(cycle_time_320oz)
std_dev_set_340oz = np.std(cycle_time_340oz)
std_dev_set_360oz = np.std(cycle_time_360oz)
std_dev_set_380oz = np.std(cycle_time_380oz)
std_dev_set_400oz = np.std(cycle_time_400oz)
std_dev_set_420oz = np.std(cycle_time_420oz)
std_dev_set_440oz = np.std(cycle_time_440oz)
std_dev_set_460oz = np.std(cycle_time_460oz)
std_dev_set_480oz = np.std(cycle_time_480oz)
std_dev_set_500oz = np.std(cycle_time_500oz)


# Calculate mean for each set
mean_set_0oz = np.mean(cycle_time_0oz)
mean_set_20oz = np.mean(cycle_time_20oz)
mean_set_40oz = np.mean(cycle_time_40oz)
mean_set_60oz = np.mean(cycle_time_60oz)
mean_set_80oz = np.mean(cycle_time_80oz)
mean_set_100oz = np.mean(cycle_time_100oz)
mean_set_120oz = np.mean(cycle_time_120oz)
mean_set_140oz = np.mean(cycle_time_140oz)
mean_set_160oz = np.mean(cycle_time_160oz)
mean_set_180oz = np.mean(cycle_time_180oz)
mean_set_200oz = np.mean(cycle_time_200oz)
mean_set_220oz = np.mean(cycle_time_220oz)
mean_set_240oz = np.mean(cycle_time_240oz)
mean_set_260oz = np.mean(cycle_time_260oz)
mean_set_280oz = np.mean(cycle_time_280oz)
mean_set_300oz = np.mean(cycle_time_300oz)
mean_set_320oz = np.mean(cycle_time_320oz)
mean_set_340oz = np.mean(cycle_time_340oz)
mean_set_360oz = np.mean(cycle_time_360oz)
mean_set_380oz = np.mean(cycle_time_380oz)
mean_set_400oz = np.mean(cycle_time_400oz)
mean_set_420oz = np.mean(cycle_time_420oz)
mean_set_440oz = np.mean(cycle_time_440oz)
mean_set_460oz = np.mean(cycle_time_460oz)
mean_set_480oz = np.mean(cycle_time_480oz)
mean_set_500oz = np.mean(cycle_time_500oz)


# Display standard deviation with two decimal places, and mean for context
print(f"Set 0oz : Mean = {mean_set_0oz:.2f}, Std Dev = {std_dev_set_0oz:.2f}")
print(f"Set 20oz : Mean = {mean_set_20oz:.2f}, Std Dev = {std_dev_set_20oz:.2f}")
print(f"Set 40oz: Mean = {mean_set_40oz:.2f}, Std Dev = {std_dev_set_40oz:.2f}")
print(f"Set 60oz: Mean = {mean_set_60oz:.2f}, Std Dev = {std_dev_set_60oz:.2f}")
print(f"Set 80oz: Mean = {mean_set_80oz:.2f}, Std Dev = {std_dev_set_80oz:.2f}")
print(f"Set 100oz: Mean = {mean_set_100oz:.2f}, Std Dev = {std_dev_set_100oz:.2f}")
print(f"Set 120oz : Mean = {mean_set_120oz:.2f}, Std Dev = {std_dev_set_120oz:.2f}")
print(f"Set 140oz: Mean = {mean_set_140oz:.2f}, Std Dev = {std_dev_set_140oz:.2f}")
print(f"Set 160oz: Mean = {mean_set_160oz:.2f}, Std Dev = {std_dev_set_160oz:.2f}")
print(f"Set 180oz: Mean = {mean_set_180oz:.2f}, Std Dev = {std_dev_set_180oz:.2f}")
print(f"Set 200oz: Mean = {mean_set_200oz:.2f}, Std Dev = {std_dev_set_200oz:.2f}")
print(f"Set 220oz : Mean = {mean_set_220oz:.2f}, Std Dev = {std_dev_set_220oz:.2f}")
print(f"Set 240oz: Mean = {mean_set_240oz:.2f}, Std Dev = {std_dev_set_240oz:.2f}")
print(f"Set 260oz: Mean = {mean_set_260oz:.2f}, Std Dev = {std_dev_set_260oz:.2f}")
print(f"Set 280oz: Mean = {mean_set_280oz:.2f}, Std Dev = {std_dev_set_280oz:.2f}")
print(f"Set 300oz: Mean = {mean_set_300oz:.2f}, Std Dev = {std_dev_set_300oz:.2f}")
print(f"Set 320oz : Mean = {mean_set_320oz:.2f}, Std Dev = {std_dev_set_320oz:.2f}")
print(f"Set 340oz: Mean = {mean_set_340oz:.2f}, Std Dev = {std_dev_set_340oz:.2f}")
print(f"Set 360oz: Mean = {mean_set_360oz:.2f}, Std Dev = {std_dev_set_360oz:.2f}")
print(f"Set 380oz: Mean = {mean_set_380oz:.2f}, Std Dev = {std_dev_set_380oz:.2f}")
print(f"Set 400oz: Mean = {mean_set_400oz:.2f}, Std Dev = {std_dev_set_400oz:.2f}")
print(f"Set 420oz : Mean = {mean_set_420oz:.2f}, Std Dev = {std_dev_set_420oz:.2f}")
print(f"Set 440oz: Mean = {mean_set_440oz:.2f}, Std Dev = {std_dev_set_440oz:.2f}")
print(f"Set 460oz: Mean = {mean_set_460oz:.2f}, Std Dev = {std_dev_set_460oz:.2f}")
print(f"Set 480oz: Mean = {mean_set_480oz:.2f}, Std Dev = {std_dev_set_480oz:.2f}")
print(f"Set 500oz: Mean = {mean_set_500oz:.2f}, Std Dev = {std_dev_set_500oz:.2f}")
# Out:
# Set 0oz : Mean = 485.11, Std Dev = 28.41
# Set 20oz : Mean = 541.77, Std Dev = 28.87
# Set 40oz: Mean = 764.53, Std Dev = 28.53
# Set 60oz: Mean = 1330.73, Std Dev = 31.24
# Set 80oz: Mean = 1332.13, Std Dev = 31.93
# Set 100oz: Mean = 1495.62, Std Dev = 48.83
# Set 120oz : Mean = 1509.16, Std Dev = 37.21
# Set 140oz: Mean = 1554.81, Std Dev = 43.52
# Set 160oz: Mean = 1831.19, Std Dev = 66.15
# Set 180oz: Mean = 1976.24, Std Dev = 67.12
# Set 200oz: Mean = 2013.58, Std Dev = 54.77
# Set 220oz : Mean = 2090.33, Std Dev = 59.55
# Set 240oz: Mean = 2124.73, Std Dev = 39.37
# Set 260oz: Mean = 2135.68, Std Dev = 50.31
# Set 280oz: Mean = 2367.20, Std Dev = 65.50
# Set 300oz: Mean = 2548.11, Std Dev = 51.64
# Set 320oz : Mean = 2578.83, Std Dev = 49.35
# Set 340oz: Mean = 2593.76, Std Dev = 49.15
# Set 360oz: Mean = 2595.74, Std Dev = 39.26
# Set 380oz: Mean = 2622.71, Std Dev = 28.18
# Set 400oz: Mean = 2616.51, Std Dev = 46.85
# Set 420oz : Mean = 2609.41, Std Dev = 46.27
# ...

# %%
# Visualizing Cycle Time Distributions at Different Fluid Depths

# In this set of histograms, we visualize the distribution of cycle times obtained from our capacitive depth sensor
# at various fluid depths. Each subplot represents a different fluid depth, and the histograms provide insights into
# the frequency distribution of cycle times at each depth. The x-axis represents cycle time, and the y-axis
# represents the frequency of occurrences.

# Create a list of all data collections
all_data_collections = [cycle_time_0oz, cycle_time_20oz, cycle_time_40oz, cycle_time_60oz, cycle_time_80oz, 
                        cycle_time_100oz, cycle_time_120oz, cycle_time_140oz, cycle_time_160oz, cycle_time_180oz, 
                        cycle_time_200oz, cycle_time_220oz, cycle_time_240oz, cycle_time_260oz, cycle_time_280oz, 
                        cycle_time_300oz, cycle_time_320oz, cycle_time_340oz, cycle_time_360oz, cycle_time_380oz, 
                        cycle_time_400oz, cycle_time_420oz, cycle_time_440oz, cycle_time_460oz, cycle_time_480oz, 
                        cycle_time_500oz]

# Manually provide a list of titles
titles = ['Distribution - 0oz', 'Distribution - 20oz', 'Distribution - 40oz', 'Distribution - 60oz', 
          'Distribution - 80oz', 'Distribution - 100oz', 'Distribution - 120oz', 'Distribution - 140oz', 'Distribution - 160oz', 
          'Distribution - 180oz', 'Distribution - 200oz', 'Distribution - 220oz', 'Distribution - 240oz', 'Distribution - 260oz', 
          'Distribution - 280oz', 'Distribution - 300oz', 'Distribution - 320oz', 'Distribution - 340oz', 'Distribution - 360oz', 
          'Distribution - 380oz', 'Distribution - 400oz', 'Distribution - 420oz', 'Distribution - 440oz', 'Distribution - 460oz', 
          'Distribution - 480oz', 'Distribution - 500oz']

# Plot histograms for all data collections
plt.figure(figsize=(15, 15))  # Adjust the figure size as needed

for i, data_collection in enumerate(all_data_collections):
    plt.subplot(5, 6, i + 1)  # Adjust the layout as needed
    plt.hist(data_collection, bins=20, edgecolor='black')
    plt.xlabel('Cycle Time')
    plt.ylabel('Frequency')
    
    # Use the manually provided titles
    plt.title(titles[i])

plt.tight_layout()
plt.show()

# %%
fluid_levels = np.array([0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500])
capacitance_readings = np.array([mean_set_0oz, mean_set_20oz, mean_set_40oz, mean_set_60oz, mean_set_80oz, mean_set_100oz, 
                                 mean_set_120oz, mean_set_140oz, mean_set_160oz, mean_set_180oz, mean_set_200oz,
                                mean_set_220oz, mean_set_240oz, mean_set_260oz, mean_set_280oz, mean_set_300oz,
                                mean_set_320oz, mean_set_340oz, mean_set_360oz, mean_set_380oz, mean_set_400oz,
                                mean_set_420oz, mean_set_440oz, mean_set_460oz, mean_set_480oz, mean_set_500oz,])

# %%
def quadratic_equation(x, a, b, c):
    """
    Computes the quadratic equation y = ax^2 + bx + c.

    Parameters:
    - x (array-like): Independent variable.
    - a (float): Coefficient of the quadratic term.
    - b (float): Coefficient of the linear term.
    - c (float): Constant term.

    Returns:
    array-like: Dependent variable values based on the quadratic equation.
    """
    return a * x**2 + b * x + c

# %%
params, covariance = curve_fit(quadratic_equation, fluid_levels, capacitance_readings)

# %%
# Scatter plot depicting the relationship between Fluid Depth (cm) and Cycle Time (μs)
# Each data point represents a specific fluid depth, and the red dashed line represents the fitted
# quadratic curve based on the proposed quadratic equation.

plt.scatter(fluid_levels, capacitance_readings, label='Original Data')
plt.plot(fluid_levels, quadratic_equation(fluid_levels, *params), 'r--', label='Fitted Quadratic Curve')
plt.xlabel('Volume oz')
plt.ylabel('Cycle Time μs')
plt.legend()
plt.show()

# %%
print('Optimized Parameters (a, b, c):', params)
print('Covariance Matrix:')
print(covariance)
# Out:
# Optimized Parameters (m, b): [-1.14713889e-02  9.90607429e+00  5.06578930e+02]
# Covariance Matrix:
# [[ 9.10630773e-07 -4.55315388e-04  3.64252311e-02]
#  [-4.55315388e-04  2.43976199e-01 -2.22922417e+01]
#  [ 3.64252311e-02 -2.22922417e+01  2.84408208e+03]]

# %%
# If we plug the optimized parameters into our quadratic equation, and solve for depth, we now have a formula 
# that we can use to estimate the current volume of liquid based on cycle time

# y = ax**2 + bx + c
# cycle_time =  -.011471388 * depth**2 + 9.90607429 * depth + 506.578930 
# depth = (-9.906074 + sqrt(9.906074**2 - 4(-.0114713)(506.57893 - cycle_time))) / 0.022942

# %%
import math

def calculate_depth(cycle_time):
    a = -.011471388
    b = 9.90607429
    c = 506.578930
    
    
    # Calaculate the discriminant inside the square rot
    discriminant = b**2 - 4 * a * (c - cycle_time)
    
    
    if discriminant >= 0:
        # Calculate the square root
        square_root_value = math.sqrt(discriminant)

        # Use the quadratic formula to find the roots
        root1 = (-b + square_root_value) / (2*a)
        root2 = (-b - square_root_value) / (2*a)
        if root2 > 0 and root2 <= 500:
            return root2
        elif root1 > 0 and root1 <= 500:
            return root1
        else:
            return 0
    return 0    

print(calculate_depth(500))
print(calculate_depth(750))
print(calculate_depth(1000))
print(calculate_depth(1500))
print(calculate_depth(2000))
print(calculate_depth(2500))
print(calculate_depth(3000))
# Out:
# 0
# 25.31502460603679
# 53.07161250600289
# 115.8172229024565
# 194.62037073455002
# 319.2798965735036
# 0
